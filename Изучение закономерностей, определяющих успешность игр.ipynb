# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Эдуард :) Спасибо за работу
#
# На проекте мы изучали и практиковали навыки из разделов о/об:
#
#  + выдвижении гипотез о пропусках в данных, заполнении или удалении,
#  + работе с категориальными данными
#  + подготовке данных для решения главной задачи проекта
#  + исследовании неочищенных данных,
#  + подборе и создании графиков,
#  + программировании,
#  + автоматизации однотипных действий,
#  + выстраивании структуры проекта и обеспечении аккуратности кода,
#  + анализе данных,
#  + определении прибыльности и устойчивости продаж по выбранному параметру (жанр, платформа) на диаграмме размаха,
#  + составлении портрета пользователя,
#  + формулировании и проверке двухсторонних гипотез, интерпретации значения p-value - можно повторить недели через две </b>(для профилактики :) )
#  + формировании рекомендаций для бизнеса
#
# <b>Навыки первого модуля освоены хорошо</b>
#
# <b>Поздравляю с успешно сданным сборным проектом и завершением первого модуля <br />на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Ринат! Привет!) вроде все исправил. И хотел спросить есть ли возможность задать вопрос в личку? (мессенджеры), если что то не получается,
#         а решить надо быстро. Переживаю, не уложиться в сроки.
#
#  P.S. графики предыдущие (топ 5)оставил себе  для  примера на будущее

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Эдуард :) Я надеюсь, уложимся в сроки, осталось немного
#
#
# Критический ❌ комментарий:
#
#  + ознакомиться с диаграммой размаха в подразделе оценки жанров
#  + в разделе проверки гипотез поправить код фильтрации, в двух стат
#  + ознакомиться с расшифровкой р-значения
#
# подсказки оставил, добавил бонус
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#  + ознакомиться с диаграммой размаха в подразделе оценки жанров - ознакомлен
#  + в разделе проверки гипотез поправить код фильтрации, в двух стат - заглушки исключил
#  + ознакомиться с расшифровкой р-значения- ознакомлен

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Эдуард :) Спасибо за все исправления и комментарии
#
#
# Критические ❌ комментарии связаны с неточностями:
#
#  + сократить категории в рейтингах ESRB — на твое усмотрение
#  + оценить прибыльность жанров на диаграмме размаха
#  + перестроить графики в ТОП-5
#  + в разделе проверки гипотез можно более подробно расшифровать значение p_value, поправить код фильтрации
#
#
# Стоит обратить внимание на ⚠️ комментарии...
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Эдуард :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# # ВЫЯВЛЕНИЕ ЗАКОНОМЕРНОСТЕЙ ОПРЕДЕЛЯЮЩИХ УСПЕХ ИГР НА МИРОВОМ РЫНКЕ И ОПРЕДЕЛЕНИЕ СТРАТЕГИИ БУДУЩИХ РЕКЛАМНЫХ КАМПАНИЙ
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# **ПЛАН РАБОТЫ С ПРОЕКТОМ:**

# %% [markdown]
# <div class="alert alert-info">
# <b>
#
#
# **Шаг 1. Откройте файл с данными и изучите общую информацию**
#
# Путь к файлу: /datasets/games.csv. Скачать датасет
#
# **Шаг 2. Подготовьте данные**
# Замените названия столбцов (приведите к нижнему регистру);
#
# Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
#
# Обработайте пропуски при необходимости:
#
# Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
#
#
# Опишите причины, которые могли привести к пропускам;
#
# Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать;
#
# Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
# Шаг 3. Проведите исследовательский анализ данных
#
# Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
#
# Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
#
# Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
#
# Не учитывайте в работе данные за предыдущие годы.
#
# Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
#
# Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
#
# Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
#
# Соотнесите выводы с продажами игр на других платформах.
#
# Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# Шаг 4. Составьте портрет пользователя каждого региона
#
# Определите для пользователя каждого региона (NA, EU, JP):
# Самые популярные платформы (топ-5). Опишите различия в долях продаж.
#
# Самые популярные жанры (топ-5). Поясните разницу.
#
# Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# Шаг 5. Проверьте гипотезы
#
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#
# Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# Задайте самостоятельно пороговое значение alpha.
#
# Поясните:
#
# Как вы сформулировали нулевую и альтернативную гипотезы;
#
# Какой критерий применили для проверки гипотез и почему.
#
# Шаг 6. Напишите общий вывод
#
#
# </div>

# %% [markdown]
# **Описание данных**
#
# Name — название игры
#
# Platform — платформа
#
# Year_of_Release — год выпуска
#
# Genre — жанр игры
#
# NA_sales — продажи в Северной Америке (миллионы проданных копий)
#
# EU_sales — продажи в Европе (миллионы проданных копий)
#
# JP_sales — продажи в Японии (миллионы проданных копий)
#
# Other_sales — продажи в других странах (миллионы проданных копий)
#
# Critic_Score — оценка критиков (максимум 100)
#
# User_Score — оценка пользователей (максимум 10)
#
# Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Ясная и четкая вступительная часть проекта

# %% [markdown]
# ## Откроем  файл с данными и изучим общую информацию, импортируем необходимые библиотеки

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
from scipy import stats as st

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец, что делишь блоки загрузки библиотек и датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %%
games = pd.read_csv('/datasets/games.csv')# прочтем файл

# %%
games.head(10)# получим общее представление(внешний вид) о датафрейме
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %%
games.shape # посмотрим размер таблицы
# Out:
# (16715, 11)

# %%
games.info() #  выведем сводную информацию о датафрейме
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
(games.isna().mean())*100 # посмотрим количество пропусков
# Out:
# Name                0.011965
# Platform            0.000000
# Year_of_Release     1.609333
# Genre               0.011965
# NA_sales            0.000000
# EU_sales            0.000000
# JP_sales            0.000000
# Other_sales         0.000000
# Critic_Score       51.319174
# User_Score         40.089740
# Rating             40.478612
# dtype: float64

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />добавим наглядности

# %%
# check
def isna_view (df):
    return  (
                (df.isna().mean()*100)
                .sort_values(ascending=False)
                .to_frame()
                .rename(columns = {0:'percent_space'})
                .style.background_gradient('coolwarm').format("{:.1f}")
            )

isna_view (games)
# Out:
# <style  type="text/css" >
# #T_27beb_row0_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_27beb_row1_col0{
#             background-color:  #f08a6c;
#             color:  #000000;
#         }#T_27beb_row2_col0{
#             background-color:  #f18d6f;
#             color:  #000000;
#         }#T_27beb_row3_col0{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_27beb_row4_col0,#T_27beb_row5_col0,#T_27beb_row6_col0,#T_27beb_row7_col0,#T_27beb_row8_col0,#T_27beb_row9_col0,#T_27beb_row10_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_27beb_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >percent_space</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_27beb_level0_row0" class="row_heading level0 row0" >Critic_Score</th>
# ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> круто, спасибо!

# %%
games.duplicated().sum() # проверим есть ли дубликаты
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Проверка на поиск дубликатов выполнена, молодец
#
# Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса

# %%
games['Platform'].value_counts() # посмотрим игры каких платформ присутствуют
# Out:
# PS2     2161
# DS      2151
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      430
# PS4      392
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# GB        98
# NES       98
# DC        52
# GEN       29
# NG        12
# WS         6
# SCD        6
# 3DO        3
# TG16       2
# PCFX       1
# GG         1
# Name: Platform, dtype: int64

# %%
games['Genre'].value_counts() #посмотрим название жанров и есть ли дубликаты в виде неверно прописанных наименований
# Out:
# Action          3369
# Sports          2348
# Misc            1750
# Role-Playing    1498
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       873
# Fighting         849
# Strategy         683
# Puzzle           580
# Name: Genre, dtype: int64

# %% [markdown]
# <div class="alert alert-info">
# <b>
#
# **Вывод:**
# **-Таблица состоит из 11 столбцов и 16715 строк**
# **-Не все данные(Year_of_Release,  User_Score) имеют верный тип**
# **-Явные дубликаты отсутствуют**
# **-Имеются пропущенные значения (Critic_Score, User_Score , Rating,- около половины значений пропущено; Year_of_Release- пропущено незначительное количество)**
# **-Названия платформ и жанров внешне выглядят хорошо, опечаток и дубликатов необнаружено**
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> загрузка и обзор данных проведены корректно

# %% [markdown]
# ## Подготовка данных для анализа

# %% [markdown]
# ### **Заменим названия столбцов (приведем к нижнему регистру)**

# %%
games.columns = games.columns.str.lower()
games.columns # проверим
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит привести к нижнему регистру и содержимое категориальных столбцов, в т.ч. с целью поиска дубликатов

# %% [markdown]
#  ### **Преобразуем данные в нужные типы**

# %%
games['year_of_release'] = games['year_of_release'].astype('Int64')# приведем годы к целому числу, дата не выражается дробным числом

# %% [markdown]
# **При попытке преобразования данных на верный тип  в стобце user_score столкнулся с проблемой, что значение tbd не возможно
# преобразовать во float64. Посмотрим, что это. Сформируем список уникальных значений в данном столбце**

# %%
games['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# **Яндекс говорит : TBD Итак, пришло время более детально рассмотреть конкретное сокращение,
#     которое часто используется в сфере компьютерных игр - TBD. Что значит это сокращение?
#     На самом деле, здесь все довольно просто. Как и в случае с предыдущими примерами,
#     эта аббревиатура не скрывает в себе никаких таинственных смыслов и расшифровывается очень просто
#     - To Be Determined, то есть "Будет определено". Очень часто подобное сокращение можно встретить
#     в анонсах компьютерных игр в графе "Дата выхода". Когда разработчик той или иной игры уже сообщил о том,
#     что она готовится к выходу, но пока еще не может назвать точную дату, именно это сокращение и используется.
#     Естественно, оно может применяться и в других случаях, но данный вариант является самым распространенным.
#     Стоит отметить также, что у этой аббревиатуры могут быть и иные значения, например To Be Done - должно быть сделано,
#     или To Be Discussed - подлежит обсуждению. Однако в данном случае это, скорее, варианты для деловой переписки,
#     в которой также периодически встречаются сокращения, которые вряд ли будут понятны среднестатистическому человеку.
#     Теперь вы понимаете, что собой представляет сокращение TBD. Dota 2 - это игра, в которой оно также используется.**
#
# *соответственно игра еще не имеет оценок или еще не вышла, имеет смысл заменить значение понятным NAN*

# %%
games['user_score'] = games['user_score'].replace('tbd', np.nan, regex=True) # заменить непонятное для phyton tbd на знакомое NAN

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Верно, по своей сути tbd и является Nan. Отлично, что определяешь неявные пропущенные значения.

# %%
 games['user_score'] = games['user_score'].astype('float64')# приведем оценки пользователей  к дробному числу, данное выражение не может быть типом обьект

# %%
games['year_of_release'] # проверим что получилось
# Out:
# 0        2006
# 1        1985
# 2        2008
# 3        2009
# 4        1996
#          ...
# 16710    2016
# 16711    2006
# 16712    2016
# 16713    2003
# 16714    2016
# Name: year_of_release, Length: 16715, dtype: Int64

# %%
games['user_score'] # проверим что получилось
# Out:
# 0        8.0
# 1        NaN
# 2        8.3
# 3        8.0
# 4        NaN
#         ...
# 16710    NaN
# 16711    NaN
# 16712    NaN
# 16713    NaN
# 16714    NaN
# Name: user_score, Length: 16715, dtype: float64

# %% [markdown]
# ### **Посмотрим на пропуски и что с ними можно сделать**

# %%
games.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         9125
# rating             6766
# dtype: int64

# %%
games[games['name'].isna()] # пропуски в столбце name и  genre совпадают и никак не повлияют на результат, так как их количество ничтожно
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN             1993   NaN      1.78      0.53      0.00
# 14244  NaN      GEN             1993   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score rating
# 659           0.08           NaN         NaN    NaN
# 14244         0.00           NaN         NaN    NaN

# %%
games = games.dropna(subset = ['name'])# поэтому удалим их

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Верное решение

# %%
games[games['year_of_release'].isna()].sample(20)# посмотрим на пропуски в столбце год релиза
# Out:
#                                                     name platform  \
# 456                           LEGO Batman: The Videogame      Wii
# 16059                             Dance! It's Your Stage      Wii
# 8364                                Sword of the Samurai      PS2
# 12784            Tom Clancy's Rainbow Six: Critical Hour       XB
# 12524                               Chou Soujuu Mecha MG       DS
# 15081                        Wii de Asobu: Metroid Prime      Wii
# 13195                                Tour de France 2011     X360
# 15535                           Runaway: A Twist of Fate       DS
# 627                                            Rock Band     X360
# 5588                                    Final Fantasy XI      PS2
# 11943                                   Dream Trigger 3D      3DS
# 6255   The Legend of Zelda: The Minish Cap(weekly JP ...      GBA
# 6954                                             Jet X20      PS2
# ...

# %% [markdown]
# **Посмотрев на названия игр можно заметить , что очередной релиз добавляет к названию цифру, то есть очередность, либо имеет уникальное название, и данный столбец не имеет пропусков поэтому имеет смысл заполнить пропуски в столбце year_of_releace на те же значения , имеющиеся в строках  с аналогичным названием игры**

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />проверим корректность алгоритма заполнения пропусков

# %%
# посмотрим в каких годах больше всего пропусков
(games['year_of_release'].value_counts()/games['year_of_release'].notna().sum()*100).head(20)
# Out:
# 2008    8.677937
# 2009    8.671856
# 2010    7.631963
# 2007    7.279251
# 2011    6.908295
# 2006    6.117733
# 2005    5.710289
# 2002    5.041352
# 2003    4.712965
# 2004    4.633909
# 2012    3.971053
# 2015    3.685235
# 2014    3.533204
# 2013    3.308198
# 2016    3.052785
# 2001     2.93116
# 1998    2.304792
# 2000    2.128436
# 1999    2.055461
# 1997     1.75748
# Name: year_of_release, dtype: Float64

# %% [markdown]
# **Всего пропусков по столбцу год релиза минимальное количество,
# а если смотреть на те года,
# которые требуются для анализа, количество ничтожное:**
# **2014г-3,53%
#   2015г-3,68%
#   2016г-3,05%**

# %%
# посмтрим пропуски по платформам
games.loc[games['year_of_release'].isna(),'platform'].value_counts()
# Out:
# Wii     34
# PS2     34
# X360    30
# DS      30
# PS3     25
# XB      21
# 2600    17
# PC      17
# PSP     16
# GC      14
# GBA     11
# 3DS      8
# PS       7
# N64      3
# PSV      1
# GB       1
# Name: platform, dtype: int64

# %% [markdown]
# **Более того платформы с пропуском в данном столбце не интересны для анализа
# так как по состоянию на 2017 год не являются актуальными и потенциально прибыльными**

# %%
# растанемся с пропусками в данном стобце
games = games.dropna(subset = ['year_of_release'])

# %%
# проверим результат
games['year_of_release'].isna().sum()
# Out:
# 0

# %%
# жизненный срок платформы

years_of_life = games.pivot_table(index='platform',values='year_of_release',aggfunc=['min','max'])
years_of_life.columns=['min','max']
years_of_life['years_of_life']=years_of_life['max']-years_of_life['min']
years_of_life

 #years_of_life.sort_values(by = 'years_of_life', ascending = False)
# Out:
#            min   max  years_of_life
# platform
# 2600      1980  1989              9
# 3DO       1994  1995              1
# 3DS       2011  2016              5
# DC        1998  2008             10
# DS        1985  2013             28
# GB        1988  2001             13
# GBA       2000  2007              7
# GC        2001  2007              6
# GEN       1990  1994              4
# GG        1992  1992              0
# N64       1996  2002              6
# NES       1983  1994             11
# NG        1993  1996              3
# PC        1985  2016             31
# PCFX      1996  1996              0
# PS        1994  2003              9
# PS2       2000  2011             11
# PS3       2006  2016             10
# PS4       2013  2016              3
# PSP       2004  2015             11
# PSV       2011  2016              5
# SAT       1994  1999              5
# SCD       1993  1994              1
# SNES      1990  1999              9
# TG16      1995  1995              0
# ...

# %%
# закомментируем неверный код( оставил для себя, для примера работы функции)
#for i in games[games['year_of_release'].isna() == True].index:  
    #games['year_of_release'][i] = games.loc[games['name'] == games['name'][i], 'year_of_release'].max()
    # напишем функцию заменяющую пустые значения на год выпуска игры, если название совпадает

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Мы внесли искажения в колонку год выпуска игры, которые приводят к ошибкам при определении срока жизни платформ
#
# Стоит посмотреть на платформы, к которым относятся пропуски, __и с легкостью расстанешься с ними ...__
#
# Рекомендуется прежде чем, выполнять проект минут 15-30 посвятить теме анализа (поиск в интернете), чтобы уверенно плавать в океане противоречивых данных :)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Действительно не заметил искажения , внес исправления!

# %% [markdown]
# **Пропусков  в столбцах critic_score, user_score досточно много, это половина всех данных, удалять их нельзя,
# заполнить средним или медианой тоже будет неверно, поэтому заполним значением "-1"
# Пропуски в столбце рейтинг обозначим как рейтинг неизвестен: unknown**

# %%
games['user_score'] = games['user_score'].fillna(-1)
games['critic_score'] = games['critic_score'].fillna(-1)
games['rating'] = games['rating'].fillna('unknown')

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отличное решение для столбца, который содержит категориальные данные, поможет определить ключевое различие в потрете пользователя
#
#        games['rating'] = games['rating'].fillna('unknown')
#
# Можно посмотреть на частотность использования категорий рейтинга, по отношению к остальным
#
#         EC         8
#         K-A        3
#         RP         1
#         AO         1

# %% [markdown]
# ### Посчитаем суммарные продажи во всех регионах и запишем  их в отдельный столбец.

# %%
games['general_sales'] = games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']
# создадим новый столбец general_sales и суммируем продажи по столбцам

# %%
games.head(10) # проверим результат
# Out:
#                         name platform  year_of_release         genre  \
# 0                 Wii Sports      Wii             2006        Sports
# 1          Super Mario Bros.      NES             1985      Platform
# 2             Mario Kart Wii      Wii             2008        Racing
# 3          Wii Sports Resort      Wii             2009        Sports
# 4   Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                     Tetris       GB             1989        Puzzle
# 6      New Super Mario Bros.       DS             2006      Platform
# 7                   Wii Play      Wii             2006          Misc
# 8  New Super Mario Bros. Wii      Wii             2009      Platform
# 9                  Duck Hunt      NES             1984       Shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 0     41.36     28.96      3.77         8.45          76.0         8.0
# ...

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# можно
#
#     df['total_sales'] = df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Спасибо! Учту на будущее!

# %% [markdown]
# <div class="alert alert-info">
# <b>
# ВЫВОД:
#
# Заменил названия столбцов (приведите к нижнему регистру;
#
# Преобразовал данные в нужные типы:
# Year_of_Release -преобразован в целое число, User_Score-преобразован в дробное число;
#
# Обработал пропуски: столбец year_of_release	не имеют значения для будущего анализа поэтому удаляем
#
# Пропуски в столбцах: critic_score, user_score заполнять средним или медианным значением будет неверно,
#     так как оценка одной и той же игры на разных платформах могут оценены по разному,
#     удалять данные также нельзя , так как они составляют около половины данных и по ним есть продажи,
#     поэтому было принято решение заполнить значения "-1";
#
# При попытке преобразования данных на верный тип  в стобце user_score столкнулся с проблемой, что значение tbd не возможно
# преобразовать во float64.
# Яндекс говорит : TBD Итак, пришло время более детально рассмотреть конкретное сокращение,
#     которое часто используется в сфере компьютерных игр - TBD. Что значит это сокращение?
#     На самом деле, здесь все довольно просто. Как и в случае с предыдущими примерами,
#     эта аббревиатура не скрывает в себе никаких таинственных смыслов и расшифровывается очень просто
#     - To Be Determined, то есть "Будет определено". Очень часто подобное сокращение можно встретить
#     в анонсах компьютерных игр в графе "Дата выхода". Когда разработчик той или иной игры уже сообщил о том,
#     что она готовится к выходу, но пока еще не может назвать точную дату, именно это сокращение и используется.
#     Естественно, оно может применяться и в других случаях, но данный вариант является самым распространенным.
#     Стоит отметить также, что у этой аббревиатуры могут быть и иные значения, например To Be Done - должно быть сделано,
#     или To Be Discussed - подлежит обсуждению. Однако в данном случае это, скорее, варианты для деловой переписки,
#     в которой также периодически встречаются сокращения, которые вряд ли будут понятны среднестатистическому человеку.
#     Теперь вы понимаете, что собой представляет сокращение TBD. Dota 2 - это игра, в которой оно также используется.
#     Соответственно игра еще не имеет оценок или еще не вышла, имеет смысл заменить значение понятным NAN
#
# Посчитал суммарные продажи во всех регионах и записал их в отдельный столбец.
#
# </div>

# %%
# check
games.rating.value_counts()
# Out:
# unknown    6676
# E          3921
# T          2905
# M          1536
# E10+       1393
# EC            8
# K-A           3
# RP            1
# AO            1
# Name: rating, dtype: int64

# %% [markdown]
# ## Проведем исследовательский анализ данных

# %% [markdown]
# ### Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
games_of_years = games.pivot_table(index='year_of_release', values='name', aggfunc='count')# создадим сводную таблицу для подсчета количества игр по году выпуска
plt.figure(figsize=(15,5)) # построим график
sns.lineplot(data = games_of_years )
plt.title("Количество игр по году релиза")
plt.xlabel("Год релиза")
plt.ylabel("Количество игр")
plt.legend('')

# %% [markdown]
# **Представленные данные показывают статистику с 1980.
# Исходя из графика всплеск выпуска игр начинается с 1990 по 2008 гг, в данные годы активно пользовались
# различными игровыми консолями, после 2010 гг начали акивно развиваться игры для смартфонов, поэтому далее наблюдаем спад**

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Классный график, все элементы добавлены, молодец

# %% [markdown]
# ### Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?

# %%
general_sales_for_platform = (games.groupby(['platform'],as_index = False)['general_sales'].sum()
                                 .sort_values('general_sales',ascending = False))
# создадим сводную таблицу для суммирования продаж по платформам

# %%
(general_sales_for_platform.plot(kind='bar',x='platform', y='general_sales',figsize=(15,5),legend=False)
                         .set(xlabel='Платформа', ylabel='Суммарные продажи')
)
plt.show()
# построим график для визуализации результата

# %% [markdown]
# **Суммарные продажи всех платформ выглядят следующим образом☝. Платформы : PS2, X360, PS3, Wii, DS, PS абсолютные лидеры продаж , резко выбиваются  от остальных платформ.**

# %%
general_sales_for_platform.head(6) # выведем результат на экран в оцифрованным виде
# Out:
#    platform  general_sales
# 16      PS2        1233.56
# 28     X360         961.24
# 17      PS3         931.34
# 26      Wii         891.18
# 4        DS         802.78
# 15       PS         727.58

# %% [markdown]
# **Посмотрим распределение по годам по топовым платформам**

# %%
# Продажи по платформe PS2, распределение по годам.
(games.query('platform == "PS2"').pivot_table(index='year_of_release', values='general_sales', aggfunc='sum')
 .plot(kind='bar', figsize=(15,4))
)
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# **Пик продаж по PS2 с 2001 по 2005 год, далее популярность падает**

# %%
# Продажи по платформe X360, распределение по годам.
(games.query('platform == "X360"').pivot_table(index='year_of_release', values='general_sales', aggfunc='sum')
 .plot(kind='bar', figsize=(15,4))
)
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# **Пик продаж по X360 с 2007 по 2013 год, далее популярность падает**

# %%
# Продажи по платформe PS3, распределение по годам.
(games.query('platform == "PS3"').pivot_table(index='year_of_release', values='general_sales', aggfunc='sum')
 .plot(kind='bar', figsize=(15,4))
)
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# **Пик продаж по PS3 с 2007 по 2014 год, пришла на замену PS2,  далее популярность падает**

# %%
# Продажи по платформe Wii, распределение по годам.
(games.query('platform == "Wii"').pivot_table(index='year_of_release', values='general_sales', aggfunc='sum')
 .plot(kind='bar', figsize=(15,4))
)
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# **Пик продаж по Wii с 2006 по 2011 год, далее популярность падает**

# %%
# Продажи по платформe PS, распределение по годам.
(games.query('platform == "PS"').pivot_table(index='year_of_release', values='general_sales', aggfunc='sum')
 .plot(kind='bar', figsize=(15,4))
)
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# **Пик продаж по PS приходится на 90-ые**

# %%
# Продажи по платформe DS, распределение по годам.
(games.query('platform == "DS"').pivot_table(index='year_of_release', values='general_sales', aggfunc='sum')
 .plot(kind='bar', figsize=(15,4))
)
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# **Пик продаж по DS с 2005 по 2010 год, далее популярность падает**

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Странный выброс 1985 года у DS, можно посмотреть когда платформу выпустили на рынок, стоит удалить аномалию

# %%
# действительно есть аномальные значения, удалим их 
index_del= games[(games['platform']=='DS')&(games['year_of_release']==1985)].index
games.drop(index_del, inplace=True)

# %%
# Продажи по платформe DS, распределение по годам.Проверим результат
(games.query('platform == "DS"').pivot_table(index='year_of_release', values='general_sales', aggfunc='sum')
 .plot(kind='bar', figsize=(15,4))
)
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Загуглил, действительно DS выпускается с 2004 года, внес исправления

# %% [markdown]
# **Популярность любой топовой платформы находится в диапазоне 5 лет, а срок "жизни" около 10 лет**

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Отличное определение жизненного цикла продаж у платформ, молодец

# %% [markdown]
# ### Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год. Не учитывайте в работе данные за предыдущие годы.

# %% [markdown]
# **Необходимо выбрать актуальный период - период, на основании которого можно составить прогноз на 2017 год.
# Актуально будет взять период  начиная с 2014 года, так как коммерческий успех лежит в
# диапазоне 5 лет, то есть 2017 год будет 4 годом для старта самой ранней успешной платформы,
# данные по другим годам отбросим.**

# %%
# отбросим данные до 2014г. и сохраним в таблице games_aktual
games_aktual = games.query('year_of_release >= 2014').copy()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Но и слишком короткий период тоже брать не стоит

# %% [markdown]
# ### Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.

# %%
# построим график зависимости продаж от типа платформ за актуальный период с 2014 года
platform_sales_aktual = games_aktual.pivot_table(index='platform', values='general_sales', aggfunc='sum')\
.sort_values('general_sales', ascending=False).plot(kind='bar', figsize=(15,4))

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Спасибо! буду применять!

# %% [markdown]
# **Построим графики, отображающие динамику продаж по уже актуальным годам и ответим на вопрос:
# Какие платформы лидируют по продажам, растут или падают?
# На основании полученных данных выберем несколько потенциально прибыльных платформ.**

# %%
games[games['year_of_release'] >= 2014].groupby('year_of_release').agg({'general_sales':'sum'}).plot( figsize=(15,4))
# выведем общий тренд по продажам
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16443 entries, 0 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16443 non-null  object
#  1   platform         16443 non-null  object
#  2   year_of_release  16443 non-null  Int64
#  3   genre            16443 non-null  object
#  4   na_sales         16443 non-null  float64
#  5   eu_sales         16443 non-null  float64
#  6   jp_sales         16443 non-null  float64
#  7   other_sales      16443 non-null  float64
#  8   critic_score     16443 non-null  float64
#  9   user_score       16443 non-null  float64
#  10  rating           16443 non-null  object
#  11  general_sales    16443 non-null  float64
# dtypes: Int64(1), float64(7), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Можно подправить подписи оси х, в виде целых 2014, 2015 ...,
#
# искать тему Ticks and ticklabels
#
# https://matplotlib.org/stable/tutorials/text/text_intro.html

# %% [markdown]
# **Общие продажи имеют глобальный тренд на снижение, далее посмотрим как ведут себя популярные платформы**

# %%
# Продажи по платформe PS4, распределение по годам.
(games_aktual.query('platform == "PS4"').pivot_table(index='year_of_release', values='general_sales', aggfunc='sum')
 .plot(kind='bar')
)
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# **Учитывая, что прогноз делаем на 2017 года и поэтому 2016 точно не подошел к концу,
# поэтому можно сказать, что данная платформа уверенно продолжает лидировать по продажам
# и не сбавляет оборотов**

# %%
# Продажи по платформe PS3, распределение по годам.
(games_aktual.query('platform == "PS3"').pivot_table(index='year_of_release', values='general_sales', aggfunc='sum')
 .plot(kind='bar')
)
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# -**Данной платформе пришло на смену следующее поколение, продажи резко снизились**

# %%
# Продажи по платформe XOne, распределение по годам.
(games_aktual.query('platform == "XOne"').pivot_table(index='year_of_release', values='general_sales', aggfunc='sum')
 .plot(kind='bar')
)
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# **Продажи находятся относительно на одном уровне, ее стабильно покупают последние три года, но количество продаж меньше чем у платформы PS4.**

# %%
# Продажи по платформe 3DS, распределение по годам.
(games_aktual.query('platform == "3DS"').pivot_table(index='year_of_release', values='general_sales', aggfunc='sum')
 .plot(kind='bar')
)
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# **По данной платформе наблюдаем стабильный спад продаж**

# %%
# Продажи по платформe X360, распределение по годам.
(games_aktual.query('platform == "X360"').pivot_table(index='year_of_release', values='general_sales', aggfunc='sum')
 .plot(kind='bar')
)
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# **Данная платформа практически не пользуется спросом в 2016 году**

# %%
# Продажи по платформe X360, распределение по годам.
(games_aktual.query('platform == "PC"').pivot_table(index='year_of_release', values='general_sales', aggfunc='sum')
 .plot(kind='bar')
)
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# **Действительно PC достаточно хорошо себя чувствует, хотя и есть динамика на снижение,
# но это не тоже самое, когда можно сказать, что о платформе забыли..
# Вообщем must have как говорится
# Также стоит не забывать о том, что данные за 2016 год не полные,
# поэтому платформа-актуальна**

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# данные за 2016 год неполные, и делать вывод о падении продаж в 2016 году не стоит, можно сравнивать рост/падение на других промежутках, например 2015 год к 2014 ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Внес корректировки в вывод

# %% [markdown]
# **Максимально прибыльные платформы  это: PS4,XOne, 3DS**

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить перечень перспективных платформ
#
#
# 30-тилетняя история персональных компьютеров говорит, что игры для PC можно включить в рекомендацию

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Дополнено!

# %% [markdown]
# ### Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.

# %%
games_aktual['general_sales'].describe()
# Out:
# count    1689.000000
# mean        0.431883
# std         1.056109
# min         0.010000
# 25%         0.030000
# 50%         0.100000
# 75%         0.350000
# max        14.630000
# Name: general_sales, dtype: float64

# %%
# построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам
fig = plt.figure(figsize = (18,10))
sns.boxplot(data = games_aktual, y = 'general_sales', x='platform').set(title = 'Продажи топ платформ за 2014-2016 гг', xlabel = 'Платформа', ylabel = 'Суммарные продажи', ylim=(0, 3))
plt.show()

# %%
# построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам
fig = plt.figure(figsize = (18,10))
sns.boxplot(data = games_aktual, y = 'general_sales', x='platform').set(title = 'Продажи топ платформ за 2014-2016 гг', xlabel = 'Платформа', ylabel = 'Суммарные продажи') 
plt.show()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отлично, ты используешь диаграмму размаха для определения успешности платформы, молодец
#
# Для более полной оценки продаж на платформах стоит добавить график со 100% масштабом, посмотреть на максимальные продажи

# %%
games_aktual.pivot_table(index = 'platform', values = ['general_sales'],aggfunc = ['median', 'mean'])
# Out:
#                 median          mean
#          general_sales general_sales
# platform
# 3DS              0.090      0.408868
# PC               0.060      0.179139
# PS3              0.110      0.311324
# PS4              0.185      0.766356
# PSP              0.020      0.027692
# PSV              0.040      0.075932
# Wii              0.180      0.460909
# WiiU             0.190      0.588767
# X360             0.180      0.434414
# XOne             0.205      0.615614

# %% [markdown]
# **Построим «ящик с усами» по топовым играм**

# %%
top_platform = games_aktual.query('platform =="PS4" or platform =="XOne" or platform =="3DS"') # обьявим новую переменную топ 3

# %%
# построим график «ящик с усами» по играм топ 3
fig = plt.figure(figsize = (18,10))
sns.boxplot(data = top_platform, y = 'general_sales', x='platform')\
.set(title = 'Продажи топ платформ за 2014-2016 гг', xlabel = 'Платформа', ylabel = 'Суммарные продажи', ylim=(0, 3))
plt.show()

# %% [markdown]
# **Вывод:
# Медиана сильно отличается от среднего, близки xone и ps4 по всем значениям. Как вывод, дальнейший анализ можно строить на одной или двух платформах: XboxOne и PS4.**

# %% [markdown]
# ### Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.

# %% [markdown]
# **Рассмотрим на примере самой популярной платформы PS4 и XOne**

# %%
# Построим диаграмму рассеяния для платформы PS4, исключим значения (-1) в отзывах пользователей и критиков
games_platform = games_aktual.query('platform == "PS4"')
games_platform[games_platform['critic_score'] != -1].plot(kind='scatter', x='critic_score', y='general_sales')
games_platform[games_platform['user_score'] != -1].plot(kind='scatter', x='user_score', y='general_sales')
plt.show()
# Расчет коэффициента корреляции
(games_platform[(games_platform['critic_score'] != -1) & 
                (games_platform['user_score'] != -1)][['critic_score', 'user_score', 'general_sales']].corr()
)
# Out:
#                critic_score  user_score  general_sales
# critic_score       1.000000    0.546434       0.401903
# user_score         0.546434    1.000000      -0.043186
# general_sales      0.401903   -0.043186       1.000000

# %% [markdown]
# **Оценка критиков для платформы PS4  оказывает слабое влияние на продажи , так как коэффициент 0,4,
# оценка пользователей на продажи никак не  влияет**

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поправить артефакт
#
#         games_platform[games_platform['user_score'] != -10].plot(kind='scatter', x='user_score', y='general_sales')

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправлено!

# %%
# Построим диаграмму рассеяния для платформы XOne , исключим значения (-1) в отзывах пользователей и критиков
games_platform = games_aktual.query('platform == "XOne"')
games_platform[games_platform['critic_score'] != -1].plot(kind='scatter', x='critic_score', y='general_sales')
games_platform[games_platform['user_score'] != -1].plot(kind='scatter', x='user_score', y='general_sales')
plt.show()
# Расчет коэффициента корреляции
(games_platform[(games_platform['critic_score'] != -1) & 
                (games_platform['user_score'] != -1)][['critic_score', 'user_score', 'general_sales']].corr()
)
# Out:
#                critic_score  user_score  general_sales
# critic_score       1.000000    0.440977       0.422112
# user_score         0.440977    1.000000      -0.091734
# general_sales      0.422112   -0.091734       1.000000

# %% [markdown]
# **Оценка критиков для  XOne имеет слабое влияние на продажи, оценка пользователей на продажи не влияет**

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поправить артефакт
#
#         games_platform[games_platform['user_score'] != -10].plot(kind='scatter', x='user_score', y='general_sales')

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Поправил!

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Сравнение показателей на нескольких платформах, позволяет набрать вес твоему исследованию, молодец

# %% [markdown]
# ### Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %% [markdown]
# **Нарисуем столбчатую диаграмму с количеством и общей суммой продаж и расскажем о самых прибыльных жанрах, а потом посмотрим на особенности жанров с высокими и низкими продажами.**

# %%
# построим диаграмму по жанрам и количеством продаж по этим жанрам
ax = plt.gca()

pivot = games.groupby('genre').agg({'name': 'count', 'general_sales': 'sum'}).sort_values(by='name', ascending=False)

plot1 = pivot['name']
plot1.plot(kind='bar', figsize=(15,5), ec='black', ax=ax, width=0.2, position=1)

plot2 = pivot['general_sales']
plot2.plot(kind='bar', figsize=(15,5), ec='black', ax=ax, width=0.2, color='#97F0AA', position=0)

ax.legend(['Количество продаж', 'Общая сумма продаж'])

# %%
# Cгруппируем продажи по жанрам
group_genre = games_aktual.pivot_table(index='genre', values='general_sales', aggfunc='sum').sort_values(by='general_sales', ascending=False)
group_genre.reset_index()
group_genre
# Out:
#               general_sales
# genre
# Action               199.36
# Shooter              170.94
# Sports               109.48
# Role-Playing         101.44
# Misc                  37.55
# Fighting              28.22
# Racing                27.52
# Platform              18.09
# Adventure             17.55
# Simulation            13.13
# Strategy               3.96
# Puzzle                 2.21

# %% [markdown]
# **Самый продаваемый жанр игр Action , меньше всего продаж игр в жанре Puzzle.**

# %% [markdown]
# **Построим «ящик с усами» по топовым жанрам**

# %%
# обьявим новую переменную топ 5 жанров
top_genre =\
games_aktual.query\
('genre=="Action" or genre=="Shooter" or genre =="Sports" or genre=="Role-Playing" or genre=="Misc"')

# %% [markdown]
# **Посмотрим сначала «ящик с усами» по всем жанрам**

# %%
# построим график «ящик с усами» по всем  жанрам в 100% масштабе
fig = plt.figure(figsize = (15,6))
sns.boxplot(data = games_aktual, y = 'general_sales', x='genre')\
.set(title = 'Продажи топ платформ за 2014-2016 гг', xlabel = 'Жанр', ylabel = 'Суммарные продажи')
plt.ylim(0,3)
plt.show()

# %% [markdown]
# **На диаграмме размаха большого масштаба мы сможем увидеть, что у большинства жаноров имеются выбросы в данных, но о самих "ящиках" сложно что-то сказать. Посмотрим диаграмму по топ жанрам и установим лимиты на ось Y**

# %%
# построим график «ящик с усами» по топ 5 жанрам 
fig = plt.figure(figsize = (15,10))
sns.boxplot(data = top_genre, y = 'general_sales', x='genre')\
.set(title = 'Продажи топ платформ за 2014-2016 гг', xlabel = 'Жанр', ylabel = 'Суммарные продажи', ylim=(0, 3))
plt.show()

# %%
top_genre['general_sales'].describe()
# Out:
# count    1242.000000
# mean        0.498205
# std         1.155551
# min         0.010000
# 25%         0.040000
# 50%         0.120000
# 75%         0.440000
# max        14.630000
# Name: general_sales, dtype: float64

# %%
games_aktual.pivot_table(index = 'genre', values = ['general_sales'],aggfunc = ['var', 'median', 'mean'])
# Out:
#                        var        median          mean
#              general_sales general_sales general_sales
# genre
# Action            0.637093         0.090      0.322068
# Adventure         0.041269         0.030      0.094865
# Fighting          1.411471         0.125      0.470333
# Misc              0.543168         0.090      0.332301
# Platform          0.522095         0.140      0.476053
# Puzzle            0.102803         0.045      0.157857
# Racing            0.928749         0.090      0.398841
# Role-Playing      1.385997         0.110      0.459005
# Shooter           4.204827         0.515      1.335469
# Simulation        0.418511         0.100      0.298409
# Sports            1.536946         0.180      0.680000
# Strategy          0.014021         0.060      0.107027

# %% [markdown]
# **Из графика «ящик с усами» видно, что у жаноров Shooter максимально  медианные значения продаж (0,515), соответсвенно жанр является самым прибыльным.**

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит проанализировать прибыльность жанров на диаграмме размаха, сравнить медианные продажи на каждом жанре и проверить какая из них более стабильна и имеет более длинный ряд успешно продающихся игр
#
# График нарисовать __в двух масштабах с выбросами и без__ (чтобы было видно 0.75-квантиль)

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит перерисовать диаграмму размаха на актуальной полной выборке
#
#         games_aktual
#
# в двух масштабах, один = 100%, второй как у тебя — ylim=(0, 3)

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# В твоей диаграмме размаха также стоило сменить на актуальную полную выборку
#
#         games_aktual

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не совсем понял, где ошибка, я также использовал games_aktual. Код идентичный с # check , только различие было в ylim

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  я обращал внимание на выборку на втором виде
#
# ![image.png](attachment:image.png)
#
# и
#
# ![image-2.png](attachment:image-2.png)

# %%
# check
fig = plt.figure(figsize = (15,6))
sns.boxplot(data = games_aktual, y = 'general_sales', x='genre')\
.set(title = 'Продажи топ платформ за 2014-2016 гг', xlabel = 'Жанр', ylabel = 'Суммарные продажи')
plt.ylim(0,3)
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Что показывают нам две диаграммы размаха — кол-во выбросов, это игры, которые принесли максимум выручки. Т.е. можно платформы/жанры сравнить по кол-ву игр-рекордсменов, а значит определить, какая из них способна выпустить наиболее привлекательные для игроманов игры. Это про выбросы
#
# Второй вид мы используем для того, чтобы сравнить медианные продажи по платформе/жанру, чтобы уточнить в каком кол-ве продаются игры на платформе/жанре, какая из них более стабильна в продажах...
#
#
# Две хорошие статьи про диаграмму размаха
#
# [Визуализация категориальных данных](https://pyprog.pro/sns/sns_7_categorical_data.html?)
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?)

# %% [markdown]
# ##  Составим портрет пользователя каждого региона

# %% [markdown]
# ### **Определите для пользователя каждого региона (NA, EU, JP): Самые популярные платформы (топ-5). Опишите различия в долях продаж. Влияет ли рейтинг ESRB на продажи в отдельном регионе?**

# %% [markdown]
# **Изначально выясним что означает данная аббревиатура.
# ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».**

# %% [markdown]
# **Определим ТОП-5 самых популярных платформ для каждого региона, основываюсь на продажах и рейтингах платформ.**

# %%
# посмотрим продажи в каждом регионе по каждой платформе
top_platforms = games_aktual.pivot_table(index = 'platform',\
                                         values = ['na_sales', 'eu_sales', 'jp_sales', 'other_sales'], aggfunc = 'sum')

# %%
#определяем топ-5 платформ в регионе NA
top_pl_na = top_platforms.sort_values(by = 'na_sales', ascending = False).head(5).index
#все остальные платформы, кроме топ-5, заменяем на значение other. Сохраняем результат в отдельное поле. 
#По нему будет агрегировать данные.
games_aktual.loc[:, 'top_platforms'] = games_aktual.loc[:, 'platform'].where(games_aktual['platform'].isin(top_pl_na), 'other')
#агрегируем данные снова по полученным платформам, эти значения затем выведем на график
top_pl_na = games_aktual.groupby('top_platforms').agg({'na_sales':'sum'}).sort_values(by = 'na_sales')
#определяем топ-5 платформ в регионе EU
top_pl_eu = top_platforms.sort_values(by = 'eu_sales', ascending = False).head(5).index
games_aktual.loc[:, 'top_platforms'] = games_aktual.loc[:, 'platform'].where(games_aktual['platform'].isin(top_pl_eu), 'other')
top_pl_eu = games_aktual.groupby('top_platforms').agg({'eu_sales':'sum'}).sort_values(by = 'eu_sales')
#определяем топ-5 платформ в регионе JP
top_pl_jp = top_platforms.sort_values(by = 'jp_sales', ascending = False).head(5).index
games_aktual.loc[:,'top_platforms'] = games_aktual.loc[:, 'platform'].where(games_aktual['platform'].isin(top_pl_jp), 'other')
top_pl_jp = games_aktual.groupby('top_platforms').agg({'jp_sales':'sum'}).sort_values(by = 'jp_sales')

# %%
#выводим три пайчарта диаграммы рядом по каждому региону
plt.figure(figsize=(16, 5)).suptitle('Топ 5 платформ по регионам');
plt.subplot(1, 3, 1)
plt.pie(top_pl_na['na_sales'], labels = top_pl_na.index, normalize=True, autopct='%.2f%%');
plt.title('Топ платформ в Северной Америке')
plt.subplot(1, 3, 2)
plt.pie(top_pl_eu['eu_sales'], labels = top_pl_eu.index, normalize=True, autopct='%.2f%%');
plt.title('Топ платформ в Европе')
plt.subplot(1, 3, 3)
plt.pie(top_pl_jp['jp_sales'], labels = top_pl_jp.index, normalize=True, autopct='%.2f%%');
plt.title('Топ платформ в Японии');

# %% [markdown]
# **В Северной Америке и Европе лидирует платформа PS4, в Японии 3DS.
# Далее следуют графики отдельно по регионам, оставил для будущей практики**

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Скорректировал!

# %%
top_platforms # выведем данные на экран по всем регионам
# Out:
#           eu_sales  jp_sales  na_sales  other_sales
# platform
# 3DS          16.12     44.24     22.64         3.68
# PC           17.97      0.00      7.23         1.85
# PS3          25.54     11.22     22.05         9.37
# PS4         130.04     15.02     98.61        44.48
# PSP           0.00      0.36      0.00         0.00
# PSV           3.53     14.54      2.52         1.81
# Wii           2.59      0.00      2.08         0.40
# WiiU         13.15      7.31     19.36         3.16
# X360         15.49      0.08     28.30         4.35
# XOne         46.25      0.32     81.27        12.52

# %% [markdown]
# **Определим топовые платформы в Северной Америке**

# %%
# Напишим функцию для подсчета для определенного региона, посмотрим влияние продаж и рейтинга 

def region_top(region, category):
    top_platforms = (games_aktual.pivot_table(index=category,values=region, aggfunc = 'sum')
         .sort_values(by=region,ascending=False).head()).plot(kind='bar')
    
    (games_aktual
    .pivot_table(index=category, values=region, aggfunc="sum")
    .sort_values(region, ascending=False)
    .head()
    .plot(y=region, kind="pie", figsize=(8, 8),title='Доля рынка', autopct='%1.1f%%')
    )
    plt.legend(bbox_to_anchor=(0.7, 0, 0.5, 1))
    plt.show()

# %%
region_top('na_sales','platform')

# %%
# Продажи в зависимости от рейтинга в Северной Америке
region_top('na_sales','rating')

# %% [markdown]
# **Северная Америка :
# Самая популярная платформа - PS4;
# Рейтинг ESRB влияет на объём продаж игр в регионе: наиболее продаваемыми играми являются игры c рейтингом M.**

# %% [markdown]
# **Определим топовые платформы в Европе**

# %%
# топовые продажи по платформам в Европе
region_top('eu_sales','platform')

# %%
# зависимость от рейтинга в Европе
region_top('eu_sales','rating')

# %% [markdown]
# **Европа :
# Самая популярная платформа - PS4;
# Рейтинг ESRB влияет на объём продаж игр в регионе: наиболее продаваемыми играми являются игры c рейтингом M.
# Картина похожа на рынок Америки**

# %% [markdown]
# **Определим топовые платформы в Японии**

# %%
region_top('jp_sales','platform') # посмотрим топовые продажи в Японии

# %%
region_top('jp_sales','rating') # Поссмотрим что с рейтингом в Японии

# %% [markdown]
# **Япония :
# Самая популярная платформа - 3DS;
# Рейтинг ESRB не сильно влияет на объём продаж игр в регионе: наиболее продаваемыми играми являются игры без рейтинга.
# Вероятно, большинство рейтингов англоязычные и не сильно интересны на данном континенте.**

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Заполнение пропусков в рейтинге позволило определить отличия региональных рынков, молодец

# %% [markdown]
# **Вывод:
# На рынке Америки и Европы хорошо реализуется продукция с рейтингом М, что подтвекрждает ранее увиденную общемировую тенденцию. Яндекс говорит, что в Японии есть свои рейтинговые ассоциации - CERO,  поэтому сведения о ESRB для данного рынка отсутствуют.
# Также следует заметить, что рейтинг оказывает влияние на покупку в большинстве случает только для детских игр, остальное лишь вкусовые предпочтения**

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Портреты клиентов нарисованы, молодец
#
# Стоит оформить графики раздела TOП-5:
#
# + для каждого ТОП-5 - построить 3 графика рядом с помощью subplots, оптимальнее сравнивать три региона по каждому виду портрета вместе;
# + оформить "двухуровневый заголовок" - и у всех трех графиков вместе, и у каждого из трех по отдельности;
# + при анализе платформ и жанров стоит все, что не вошло в ТОП-5, объединять в категорию "другие" - так картина анализа будет более полной
#
# + перерисовать раздел жанров — три рисунка для каждого региона
#
#
# Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе
#
# https://proproprogs.ru/modules/matplotlib-otobrazhenie-neskolkih-koordinatnyh-osey-v-odnom-okne
#
# https://nagornyy.me/it/vizualizatsiia-dannykh-v-matplotlib/?ysclid=l4q3l4q0p8940570437
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html?highlight=append#pandas.DataFrame.append

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />графики стоит перерисовать

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Перерисовал

# %%
# check

# пример из ссылки

# данные для линий

x = np.linspace(0, 5, 11)
y = x**2

# строим графики

plt.subplot(1, 2, 1)
plt.plot(x, y, 'r--')  #  Магия
plt.subplot(1, 2, 2)
plt.plot(y, x, 'g*-');

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Оставляю примеры из ссылок, как расположить графики
#
# и пример какой вид графиков лучше
#
# ![image.png](attachment:image.png)
#
#
# __Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе__

# %% [markdown]
# ### Самые популярные жанры (топ-5).

# %%
#считаем медианные продажи в каждом в регионе по каждому жанру
top_genre = games_aktual.pivot_table(index = 'genre', values = ['na_sales', 'eu_sales', 'jp_sales'], aggfunc = 'median')
#определяем топ-5 жанров в регионе EU
top_genre_na = top_genre.sort_values(by = 'na_sales', ascending = False).head(5).index
games_aktual.loc[:, 'top_genre'] = games_aktual.loc[:, 'genre'].where(games_aktual['genre'].isin(top_genre_na), 'other')
top_genre_na = games_aktual.groupby('top_genre').agg({'na_sales':'median'}).sort_values(by = 'na_sales')
#определяем топ-5 жанров в регионе EU
top_genre_eu = top_genre.sort_values(by = 'eu_sales', ascending = False).head(5).index
games_aktual.loc[:,'top_genre'] = games_aktual.loc[:, 'genre'].where(games_aktual['genre'].isin(top_genre_eu), 'other')
top_genre_eu = games_aktual.groupby('top_genre').agg({'eu_sales':'median'}).sort_values(by = 'eu_sales')
#определяем топ-5 жанров в регионе JP
top_genre_jp = top_genre.sort_values(by = 'jp_sales', ascending = False).head(5).index
games_aktual.loc[:,'top_genre'] = games_aktual.loc[:, 'genre'].where(games_aktual['genre'].isin(top_genre_jp), 'other')
top_genre_jp = games_aktual.groupby('top_genre').agg({'jp_sales':'median'}).sort_values(by = 'jp_sales')

# %%
#выводим три пайчарта диаграммы рядом по каждому региону
plt.figure(figsize=(16, 5)).suptitle('Топ 5 жанров по регионам');
plt.subplot(1, 3, 1)
plt.pie(top_genre_na['na_sales'], labels = top_genre_na.index, normalize=True, autopct='%.2f%%');
plt.title('Топ жанров в Северной Америке')
plt.subplot(1, 3, 2)
plt.pie(top_genre_eu['eu_sales'], labels = top_genre_eu.index, normalize=True, autopct='%.2f%%');
plt.title('Топ жанров в Европе')
plt.subplot(1, 3, 3)
plt.pie(top_genre_jp['jp_sales'], labels = top_genre_jp.index, normalize=True, autopct='%.2f%%');
plt.title('Топ жанров в Японии');

# %% [markdown]
# **В регионах NA и EU лидирует жанр Shooter, В регионе JP можно выделить жанр Role-Playing
# Популярность жанров по регионам исследована не по общему числу продаж, а по медианным значениям,
# т.к. игры выходят на разные платформы и успех одной игры для одной платформы может быть непоказателен.**

# %% [markdown]
# ## Проверим гипотезы

# %% [markdown]
# **Для проверки используем Критерий Стьюдента (t-тест) - это статистический метод, который позволяет сравнивать средние значения двух выборок и на основе результатов теста делать заключение о том, различаются ли они друг от друга статистически или нет.**

# %% [markdown]
# ### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# **Сформулируем нулевую и альтернативную гипотезы:
# H_0: Средний user_score платформы Xbox One = Средний  user_score платформы PC
# H_1: Средний user_score платформы Xbox One != Средний user_score платформы PC
# Обе выборки независимы. Пороговое значение alpha зададим 0.05.
# С помощью метода st.ttest_ind() выполним расчёт**

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Гипотезы сформулированы верно

# %%
#зададим alpha
alpha = .05

# %%
# исключим из выборки заглушки -1
games_aktual = games_aktual.query('user_score != -1')

# %%
# Сформируем  выборки

sample_1 = games_aktual.query('platform == "XOne"')['user_score']
sample_2 = games_aktual.query('platform == "PC"')['user_score']
# помощи метода st.ttest_ind() выполним расчёт
results = st.ttest_ind(sample_1, sample_2)
print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.10450507919348415
# Не получилось отвергнуть нулевую гипотезу

# %%
# check
sample_1
# Out:
# 165      7.9
# 179      5.4
# 242      6.4
# 270      6.2
# 373      4.1
#         ...
# 16544    6.8
# 16597    6.0
# 16630    8.2
# 16643    6.6
# 16660    6.7
# Name: user_score, Length: 165, dtype: float64

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         sample_1 = games_aktual.query('platform == "XOne"')['user_score']
#         sample_2 = games_aktual.query('platform == "PC"')['user_score']
#
# У нас в выборке для стат тестов остались маркеры = -1, которые искажают результаты расчета
#
# стоит избавиться от любых видов заглушек (нулевых, отрицательных, положительных) при расчете стат. тестов
#
# В предыдущем комментарии, я говорил, что это условие излишне, т.к. у нас нет пропусков в выборке
#
#         ['user_score'].dropna()

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Заглушки исключены

# %% [markdown]
# **Вывод: Полученное значение p-value говорит о том, что хотя оценки игроков на двух платформах и неодинаковы , с вероятностью 10%  <b>такое или большее различие можно получить случайно </b> Это явно слишком большая вероятность, чтобы делать вывод о значимом различии между средними оценками пользователей двух платформ**

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Важно удалить пропуски и «заглушки» перед проведением теста, молодец

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает на языке статистики p-значение: 0.1269024252036148

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Дополнил вывод.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="4", color = "black">
# <br />Для ознакомления с корректной формулировкой расшифровки
#
# Полученное значение p-value говорит о том, что хотя оценки игроков на двух платформах и неодинаковы , с вероятностью 27%  <b>такое или большее различие можно получить случайно </b> Это явно слишком большая вероятность, чтобы делать вывод о значимом различии между средними оценками пользователей двух платформ

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Оставил пример
#
# Что означает на языке статистики p-значение: 0.10450507919348415
#
#         p-значение это уровень значимости, на котором находятся друг от друга среднее значение и то, с которым производится сравнение.
#         Наше p-значение находится между 0,05 и 0,1.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Приведу пример и теорию для понимания формулировок и интерпретации итогов проведения гипотез</b>
#
#
# Задача. Приведены два датасета: сумма покупок, совершённых за месяц посетителями, привлечёнными по двум разным каналам. В вашем распоряжении случайная выборка из 30 покупок для каждого канала.
#
# H0 - средние чеки равны
#
#
# H1 - средние чеки НЕ равны
#
# Да сама формулировка нулевой и альтернативной гипотезы звучит именно так, но результат теста интерпретируется другими словами
#
#
# <b>Из теории на тренажере</b>
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.
#
# P-значение (англ. P-value) — величина, используемая при тестировании статистических гипотез. <b>Фактически это вероятность ошибки при отклонении нулевой гипотезы (ошибки первого рода)</b> пример ниже

# %%
# Приведены два датасета: сумма покупок, совершённых за месяц посетителями ...

sample_1 = [3071, 3636, 3454, 3151, 2185, 3259, 1727, 2263, 2015,
2582, 4815, 633, 3186, 887, 2028, 3589, 2564, 1422, 1785,
3180, 1770, 2716, 2546, 1848, 4644, 3134, 475, 2686,
1838, 3352]
sample_2 = [1211, 1228, 2157, 3699, 600, 1898, 1688, 1420, 5048, 3007,
509, 3777, 5583, 3949, 121, 1674, 4300, 1338, 3066,
3562, 1010, 2311, 462, 863, 2021, 528, 1849, 255,
1740, 2596]
alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвергнем гипотезу
results = st.ttest_ind(
sample_1,
sample_2)
print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:

    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.1912450522572209
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Интерпретация результата:
#
# Полученное значение p-value говорит о том, что хотя средний чек пришедших из разных каналов и неодинаков, <b>с вероятностью в почти 19% такое или большее различие можно получить случайно. </b>Это явно слишком большая вероятность, чтобы делать вывод о значимом различии между средними чеками.
#
# А если p-value  будет равно 0,9999, то это значит, что с вероятностью почти 100% <u>такое различие</u> можно получить случайно — то есть почти никогда :)  (но учитываем, что тест проводится на выборке из генеральной совокупности, все может поменяться)

# %%
# check
games_aktual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 888 entries, 42 to 16692
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             888 non-null    object
#  1   platform         888 non-null    object
#  2   year_of_release  888 non-null    Int64
#  3   genre            888 non-null    object
#  4   na_sales         888 non-null    float64
#  5   eu_sales         888 non-null    float64
#  6   jp_sales         888 non-null    float64
#  7   other_sales      888 non-null    float64
#  8   critic_score     888 non-null    float64
#  9   user_score       888 non-null    float64
#  10  rating           888 non-null    object
#  11  general_sales    888 non-null    float64
#  12  top_platforms    888 non-null    object
#  13  top_genre        888 non-null    object
# dtypes: Int64(1), float64(7), object(6)
# memory usage: 104.9+ KB

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Код избыточный, у нас в выборке games_aktual или пропуски, или маркеры (-1)
#
#         sample_1 = games_aktual[(games_aktual['platform'] == 'XOne') & (games_aktual['user_score'] != -1)]['user_score'].dropna()
#         sample_2 = games_aktual[(games_aktual['platform'] == 'PC')  & (games_aktual['user_score'] != -1)]['user_score'].dropna()

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Код исправил!

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит оптимизировать код, у нас нет пропусков в колонке games_aktual['user_score']
#
#         Код избыточный, у нас в выборке games_aktual или пропуски, или маркеры (-1)
#
#         sample_1 = games_aktual[(games_aktual['platform'] == 'XOne') & (games_aktual['user_score'] != -1)]['user_score'].dropna()
#         sample_2 = games_aktual[(games_aktual['platform'] == 'PC')  & (games_aktual['user_score'] != -1)]['user_score'].dropna()

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные

# %% [markdown]
# **Сформулируем нулевую и альтернативную гипотезы:**
#
# **H_0: Средний user_score жанров Action == Средний user_score жанров Sports**
# **H_1: Средний user_score жанров Action != Средний user_score жанров Sports**
# **Обе выборки независимы. Пороговое значение alpha зададим 0.05.**
# **С помощью метода st.ttest_ind() выполним расчёт**

# %%
#зададим alpha
alpha = .05

# %%
# Сформируем  выборки, исключим значения , заполненные "-1"

sample_1 = games_aktual.query('genre == "Action"')['user_score']
sample_2 = games_aktual.query('genre == "Sports"')['user_score']
# помощи метода st.ttest_ind() выполним расчёт
results = st.ttest_ind(sample_1, sample_2)
print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 2.8711147985105864e-19
# Отвергаем нулевую гипотезу

# %%
# check
sample_2
# Out:
# 77       4.3
# 94       5.0
# 143      5.7
# 264      4.5
# 314      6.7
#         ...
# 16120    6.3
# 16142    8.8
# 16146    6.9
# 16518    1.4
# 16643    6.6
# Name: user_score, Length: 127, dtype: float64

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         sample_1 = games_aktual.query('genre == "Action"')['user_score']
#         sample_2 = games_aktual.query('genre == "Sports"')['user_score']
#
# У нас в выборке для стат тестов остались маркеры = -1, которые искажают результаты расчета
#
# стоит избавиться от любых видов заглушек (нулевых, отрицательных, положительных) при расчете стат. тестов

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Заглушки исключены

# %% [markdown]
# **Вывод: гипотеза -cредние пользовательские рейтинги жанров Action (англ. «действие», экшен- игры) и Sports (англ. «спортивные соревнования») разные - маловероятна**

# %% [markdown]
# **О маловероятности гипотезы также говорят расчеты среднего, произведенные ниже**

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Мы не используем слова со смыслом: подтверждена, принимается, уверенно — для описания результатов стат. тестов
#
# Стоит поправить
#
#         Вывод: гипотеза -cредние пользовательские рейтинги жанров Action (англ. «действие», экшен- игры) и Sports (англ. «спортивные соревнования») разные - не подтверждена

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Скоректировал вывод

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# можно подправить некоторые моменты
#
#         Для подтверждения наших выводов ...
#
# <b>Из теории на тренажере</b>
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.
#
# https://allatambov.github.io/psms/pdf/hypo-test.pdf

# %%
games_aktual.query('platform in ("XOne", "PC")').groupby('platform')['user_score'].agg('mean')
# Out:
# platform
# PC      6.298361
# XOne    6.594545
# Name: user_score, dtype: float64

# %%
games_aktual.query('genre in ("Action", "Sports")').groupby('genre')['user_score'].agg('mean')
# Out:
# genre
# Action    6.760606
# Sports    5.225197
# Name: user_score, dtype: float64

# %% [markdown]
# **Вывод:
# Cредние рейтинги пользователей оказались равны при сравнении платформ XOne и PC, но не равны при сравнении жанров Action и Sports.**

# %% [markdown]
#  ## Общий вывод:
# <div class="alert alert-info">
# <b>
#
# **Целью исследования было выявить закономерности определяющие успешность игры.
# Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.**
#
# **Итоги исследования:**
#
# **-Представленные данные показывают статистику с 1980.Исходя из графика всплеск выпуска игр начинается с 1990 по 2008 гг, в данные годы активно пользовались различными игровыми консолями, после 2010 гг начали акивно развиваться игры для смартфонов, поэтому далее наблюдаем спад**
#
# **-Суммарные продажи всех платформ выглядят следующим образом. Платформы : PS2, X360, PS3, Wii, DS, PS абсолютные лидеры продаж , резко выбиваются от остальных платформ.**
#
# **-Максимально прибыльные платформы это: PS4,XOne, 3DS, PC**
#
# **-Между оценками критиков и общими продажами игр обнаружена слабая зависимость. Зависимость между оценками пользователей и общими продажами почти полностью отсутствует. Это означает, что на оценки в целом не стоит обращать внимание при проведении кампании. Однако, игры с высокими оценками критиков вероятнее будут лучше продаваться.**
#
# **В регионах NA и EU лидирует жанр Shooter, В регионе JP можно выделить жанр Role-Playing**
#
# **-В Северной Америке самая популярная платформа - PS4; Рейтинг ESRB влияет на объём продаж игр в регионе: наиболее продаваемыми играми являются игры c рейтингом M.**
#
# **-В Европе самая популярная платформа - PS4; Рейтинг ESRB влияет на объём продаж игр в регионе: наиболее продаваемыми играми являются игры c рейтингом M. Картина похожа на рынок Америки**
#
# **-Для региона JP следует сделать ставку на игры жанра Role-Playing.**
#
# **-Для проведения рекламных кампаний следует сделать ставку на игры для новой платформы PS4, XOne, 3DS,т.к. выпуск игр для нее и, соответственно, продажи будут только расти. Также нужно учитывать, что спрос на платформу PC стабильный, поэтому также не исключаем**
#
# **-Cредние рейтинги пользователей оказались равны при сравнении платформ XOne и PC, но не равны при сравнении жанров Action и Sports.**
# </div>

# %% [markdown]
# 👌это на удачу! не хочу в академ😊

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Итоговый вывод технически составлен грамотно
#
#
# мы формируем рекомендацию для интернет магазина, для продажи или наполнения ассортимента, если ориентироваться только на одну платформу и один жанр это приведет к потерям и снижению уровня продаж

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты выполнил практически все пункты проекта, молодец! Проведен значительный объем исследования
#
# Критические ❌ комментарии связаны с неточностями:
#
#  + заполнение пропусков в колонке год выпуска
#  + сократить категории в рейтингах ESRB — на твое усмотрение
#  + дополнить перечень перспективных платформ
#  + оценить прибыльность жанров на диаграмме размаха
#  + перестроить графики в ТОП-5
#  + в разделе проверки гипотез можно более подробно расшифровать значение p_value
#  + перепроверить промежуточные и итоговый выводы после всех исправлений
#
# Стоит обратить внимание на ⚠️ комментарии...
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Может пригодиться
#
# [Подборка статей о работе с библиотеками для анализа данных на языке Python](https://dfedorov.spb.ru/pandas/)
#
#
# [Визуализация](https://dfedorov.spb.ru/pandas/%D0%AD%D1%84%D1%84%D0%B5%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D0%B5%20%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20Matplotlib.html)
#
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
# [Постер «Графики, которые убеждают всех»](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)
#
#
# В помощь — как реализовать интерактивный план проекта вручную (для собственных проектов), смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Ринат! Благодарю за полезные ссылки,
#         в сообществе студентов все уже говорят,
#         что ты советуешь только полезное и крутое для чтения!

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> большое спасибо тебе и всем благодарным студентам

# %% [markdown]
# ## Бонус

# %%
data_games = pd.read_csv('/datasets/games.csv')

# %%
data_games.columns = map(str.lower, data_games.columns)

# %%
data_games = data_games.dropna(subset = ['year_of_release', 'name', 'genre'])

# %%
data_games['user_score'] = data_games['user_score'].replace('tbd', np.nan).astype('float')

# %%
data_games['rating'] = data_games['rating'].fillna('unknown')

# %%
data_games['total_sales'] = data_games[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %%
# check
# круги + категория другие
def graph (df, year, region, name, axes):
    
    df = df.query('year_of_release >= @year')
    
    sales = df.pivot_table(index='platform', 
                           values=region, 
                           aggfunc='sum').nlargest(5, region)
    
    sales = sales.reset_index()
    
    sales = (
            sales.append({'platform': 'Other', region: df[region].sum() 
                       - sales[region].sum()}, ignore_index= True)
         )
    
    
    sales.columns = ['platform', 'sales']
      
    labels_c=sales.platform
    colours = {'Wii':'C0', 'NES':'C1', 'GB':'C2', 'DS':'C3', 'X360':'C4', 
    'PS3':'C5', 'PS2':'C6', 'SNES':'C7', 'GBA':'C8',
               'PS4':'steelblue', '3DS':'orange', 
               'N64':'C11', 'PS':'C12', 'XB':'C13', 'PC':'C14', '2600':'C15', 'PSP':'C16', 
               'XOne':'C17',
               'WiiU':'C18', 'GC':'C19', 'GEN':'C20', 'DC':'C21', 'PSV':'C22', 
               'SAT':'C23', 'SCD':'C24', 'WS':'C25', 'NG':'C26', 
               'TG16':'C27', '3DO':'C28', 'GG':'C29', 'PCFX':'C30', 'Other':'darkred'}
   
    sales.plot(kind='pie',
               y="sales",
               
               autopct='%1.0f%%',
               wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
               textprops={'size': 'x-large'}, 
               labels= labels_c,
               colors=[colours[key] for key in labels_c],
               legend=False, 
               title = f"Популярность платформ в {name} ", 
               ax = axes).set(ylabel='')
    
    plt.tight_layout()

# %%
# check
# круги в ряд
fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle('Обзор рынка платформ (портрет покупателя)', fontsize = 30, fontweight='bold')

x_year = 2012

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %%
# check
# круги в ряд
fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle('Обзор рынка платформ (портрет покупателя)', fontsize = 30, fontweight='bold')

x_year = 2014

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> 2015 год взят для акцентирования на изменении доли в продажах современных платформ

# %%
# check
# круги в ряд
fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle('Обзор рынка платформ (портрет покупателя)', fontsize = 30, fontweight='bold')

x_year = 2015

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Спасибо, за бонусы, сохраняю в копилку!
